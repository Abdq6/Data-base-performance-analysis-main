# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df5 = pd.read_csv('./confidence_5/delete_latencies_1000_records_1_bytes.csv')
df10 = pd.read_csv('./confidence_10/delete_latencies_1000_records_1_bytes.csv')
df15 = pd.read_csv('./confidence_15/delete_latencies_150_records_1_bytes.csv')
df20 = pd.read_csv('./confidence_20/delete_latencies_1000_records_1_bytes.csv')

# %%
df5.head()
# Out:
#        rec1      rec2      rec3      rec4      rec5      rec6      rec7  \
# 0  0.314209  0.256416  0.284645  0.309440  0.278160  0.271866  0.282165
# 1  0.339985  0.351906  0.270128  0.255108  0.239134  0.257730  0.283241
# 2  0.277042  0.258684  0.266314  0.255823  0.261068  0.277042  0.237942
# 3  0.292063  0.236034  0.259161  0.288963  0.269890  0.269890  0.271082
# 4  0.317812  0.286818  0.262022  0.233173  0.253916  0.238180  0.253916
#
#        rec8      rec9     rec10  ...    rec991    rec992    rec993    rec994  \
# 0  0.269577  0.266906  0.277397  ...  0.276634  0.254890  0.287887  0.269386
# 1  0.306845  0.258207  0.260830  ...  0.227213  0.232935  0.272989  0.268936
# 2  0.253916  0.254154  0.238895  ...  0.291824  0.296116  0.269890  0.221252
# 3  0.283003  0.263929  0.236034  ...  0.274897  0.271320  0.279665  0.253201
# 4  0.278950  0.218868  0.239134  ...  0.275135  0.240803  0.247002  0.231028
#
#      rec995    rec996    rec997    rec998    rec999   rec1000
# ...

# %%
df5 = df5.melt()
df10 = df10.melt()
df15 = df15.melt()
df20 = df20.melt()

frames = [df5, df10, df15, df20]
colors = ['green', 'blue', 'black', 'red']

# %%
fig, ax = plt.subplots(figsize=(16, 8))
plt.style.use('bmh')
for frame, color, i, name in zip(frames, colors,[1,2,3,4], [5,10,15,20]):
    sns.lineplot(data=frame[:500*i], x='variable', y='value', marker='o',color=color, label=name)

ax.set_xticklabels(np.arange(1,101,2))
plt.xticks(np.arange(0,101,2))
plt.xticks(rotation=45,fontsize=10,style='italic')
plt.xticks(rotation=45,fontsize=10,style='italic')
plt.ylim([0,0.6])
plt.xlim([-1,102])
plt.legend(fancybox=True, shadow=True, facecolor='white', edgecolor='black',title='Ilość powtórzeń',title_fontproperties={'weight':'bold'})
plt.ylabel('Opóźnienie [ms]')
plt.xlabel('Iteracja eksperymentu')
plt.savefig('./conf.svg',bbox_inches="tight")
plt.show()
# Out:
# C:\Users\kacpe\AppData\Local\Temp\ipykernel_13360\4183328951.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(np.arange(1,101,2))
